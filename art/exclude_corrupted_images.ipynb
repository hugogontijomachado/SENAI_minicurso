# %%
import cv2
import os

path='E:\\OneDrive\\Doutorado\\Cursos\\FastAI_Pierre\\Aula02-30out2019\\downloads'
#print
paths= ['{}\\{}'.format(path,x) for x in os.listdir(path)]
print(paths)
# Out:
# ['E:\\OneDrive\\Doutorado\\Cursos\\FastAI_Pierre\\Aula02-30out2019\\downloads\\caneta', 'E:\\OneDrive\\Doutorado\\Cursos\\FastAI_Pierre\\Aula02-30out2019\\downloads\\carro', 'E:\\OneDrive\\Doutorado\\Cursos\\FastAI_Pierre\\Aula02-30out2019\\downloads\\casas', 'E:\\OneDrive\\Doutorado\\Cursos\\FastAI_Pierre\\Aula02-30out2019\\downloads\\computador', 'E:\\OneDrive\\Doutorado\\Cursos\\FastAI_Pierre\\Aula02-30out2019\\downloads\\fazenda', 'E:\\OneDrive\\Doutorado\\Cursos\\FastAI_Pierre\\Aula02-30out2019\\downloads\\floresta', 'E:\\OneDrive\\Doutorado\\Cursos\\FastAI_Pierre\\Aula02-30out2019\\downloads\\geleira', 'E:\\OneDrive\\Doutorado\\Cursos\\FastAI_Pierre\\Aula02-30out2019\\downloads\\montanha', 'E:\\OneDrive\\Doutorado\\Cursos\\FastAI_Pierre\\Aula02-30out2019\\downloads\\montanhas', 'E:\\OneDrive\\Doutorado\\Cursos\\FastAI_Pierre\\Aula02-30out2019\\downloads\\predios', 'E:\\OneDrive\\Doutorado\\Cursos\\FastAI_Pierre\\Aula02-30out2019\\downloads\\vulcao']

# %%
for path in paths:
        for file in os.listdir(path):
            img = cv2.imread(os.path.join(path,folder,file))
            if img is None:
                print("\t Exclude file: {}".format(file))
                os.system("del {}".format(os.path.join(path,folder,file)))
# Out:
# 	 Exclude file: 1.canetas-enem.png
# 	 Exclude file: 10.8500001-1.jpg
# 	 Exclude file: 11.caneta-stabilo-point-88-4mm.jpg
# 	 Exclude file: 12.caneta-esfereogr_fica-cis-scrit-azul.jpg
# 	 Exclude file: 13.caneta-esferografica-cis-scrit-azul-07.jpg
# 	 Exclude file: 14.e4a371876c6015a92b7da61de821eaa6.JPG
# 	 Exclude file: 15.caneta-esferografica-trilux-medium-colors_1_1200.jpg
# 	 Exclude file: 16.caneta-plastica-inteira-colorida-8578-caneta-plastica.jpg
# 	 Exclude file: 17.caneta-esferografica-0-7mm-super-007-azul-img-58237.jpg
# 	 Exclude file: 18.91foaE0f1yL._SY679_.jpg
# 	 Exclude file: 19.180900z.jpg
# 	 Exclude file: 2.caneta-azul-azul-caneta-696x452.jpg
# 	 Exclude file: 20.caneta-diamante-cristal-esferografica-ponta-fina-lembranca-infantil.jpg
# 	 Exclude file: 21.687.jpg
# 	 Exclude file: 22.caneta-compactor-07-az.png
# 	 Exclude file: 23.Kit-Caneta-Pincel-Brush-Pastel-Newpen-6-cores.jpg
# 	 Exclude file: 24.blister_07az_az_vm_pt.jpg
# ...
